# %% [markdown]
# # 데이터 집계와 시각화
#
# ### 주요 내용
#
# 1. 건수, 합계 평균 등 집계값 계산
# 2. 히스토그램, 상자그림, 막대그래프 등 그래프 작성
#
# <br>
#
# ### 목표
# 1. 집계값을 계산할 수 있다.
# 2. 적절한 그래프를 작성하고 올바르게 해석할 수 있다.
#
#
# <br>
# <hr>
# <br>

# %% [markdown]
# ## 라이브러리 불러오기

# %%
import numpy as np
import pandas as pd
import seaborn as sns # 그래프 작성
import matplotlib.pyplot as plt

# %% [markdown]
# <br>
#
# ## 예제 및 실습 데이터 불러오기

# %%
# 데이터 불러오기
df_ins = pd.read_csv('data/insurance.csv')
df_ins.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df_sp = pd.read_csv('data/StudentsPerformance.csv')
df_sp.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# <br>
#
# ## 1. 범주형 변수의 요약과 시각화

# %%
# 수준(levels) 및 개수 확인 
df_ins['smoker'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
df_ins['smoker'].nunique()
# Out:
# 2

# %% [markdown]
# <br>
#
# ### 1.1. 수준별 관측치 수 계산

# %%
# 수준별 관측치 수 세기
df_ins['smoker'].value_counts()
# Out:
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64

# %% [markdown]
# ### 1.2. 수준별 관측치 수 막대그래프

# %%
# seaborn을 활용한 막대그래프
sns.countplot(data=df_ins,
              x='smoker')
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %% [markdown]
# <br>
#
# #### [실습]
#
# 1. 데이터 df_sp에서 'parental level of education'의 수준 목록 확인하기
# 2. 데이터 df_sp에서 'parental level of education'의 수준별 관측치 수 계산하기
# 3. 데이터 df_sp에서 'parental level of education'의 수준별 관측치 수 막대그래프 그리기
# 2. 데이터 df_sp에서 'race/ethnicity'로 위의 1~3. 반복 하기

# %%
df_sp.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# ## 1. 데이터 df_sp에서 'parental level of education'의 수준 목록 확인하기

# %%
# 어떤 목록이 있는지 확인 
df_sp['parental level of education'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %% [markdown]
# ## 2. 데이터 df_sp에서 'parental level of education'의 수준별 관측치 수 계산하기

# %%
# 수준별 관측치 수 계산하기 
df_sp['parental level of education'].value_counts()
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %% [markdown]
# ## 3.데이터 df_sp에서 'parental level of education'의 수준별 관측치 수 막대그래프 그리기

# %%
# seaborn을 활용한 막대그래프
sns.countplot(data=df_sp,
              x='parental level of education')
# Out:
# <Axes: xlabel='parental level of education', ylabel='count'>

# %%
#counts_edu = df_sp[col].value_counts(dropna=False)

# %%
# import matplotlib.pyplot as plt -> 이 라이브러리 켜야함 
# 그래프를 더 디테일하게 그릴 수 있음 
col = "parental level of education"
plt.figure(figsize=(12,5))
sns.countplot(data=df_sp, x = col, order=df_sp[col0].value_counts().index)
plt.title("Count by Parental Level of Education")
plt.xlabel("Parental level of education")
plt.ylabel("Count")
plt.xticks(rotation = 25)
plt.grid(axis ="y",alpha = 0.3)

# %% [markdown]
# ## 4. 데이터 df_sp에서 'race/ethnicity'로 위의 1~3. 반복 하기

# %%
df_sp['race/ethnicity'].unique() # 어떤 목록이 있는지 확인
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
# 수준별 관측치 수 계산하기 
df_sp['race/ethnicity'].value_counts()
# Out:
# race/ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
# seaborn을 활용한 막대그래프
sns.countplot(data=df_sp,
              x='race/ethnicity')
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='count'>

# %%
# 관심 변수 선택
df_ins['charges']
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
# 수치형 변수의 집계값 계산
    # mean( ) : 수치형 Series의 메서드
df_ins['charges'].mean()
# Out:
# np.float64(13270.422265141257)

# %%
df_ins['charges'].sum()
# Out:
# np.float64(17755824.990759)

# %%
# 분산과 표준편차계산
# df_ins['charges'].var()
df_ins['charges'].std()
# Out:
# np.float64(12110.011236694001)

# %%
# 관측치 수 계산하기
df_ins['charges'].count()
# Out:
# np.int64(1338)

# %% [markdown]
# #### 2.1.1. numpy를 활용한 집계값 계산

# %%
np.sum(df_ins['charges'])
# Out:
# np.float64(17755824.990759)

# %%
np.mean(df_ins['charges'])
# Out:
# np.float64(13270.422265141257)

# %%
np.std(df_ins['charges'], ddof=1)
# Out:
# np.float64(12110.011236694001)

# %% [markdown]
# <br>
# <br>
# <br>
#
# ## 2. 수치형 변수의 집계값과 분포 그래프
#
# 하나의 수치형 변수로 합계, 평균과 같은 집계값을 계산할 수 있고 히스토그램이나 상자그림으로 분포를 확인
#
#
# <br>
#
# ### 2.1. 수치형 변수의 집계값 계산
#
# 수치형 변수를 선택한 다음 sum( ), mean( ) 같은 메서드를 활용해서 집계값을 계산

# %% [markdown]
# <br>
#
# ### 2.2. 히스토그램 그리기
#
# 하나의 수치형변수의 분포를 파악하기 위해서 히스토그램 작성

# %%
# histplot()을 활용한 히스토그램
sns.histplot(data=df_ins,
             x='charges')
# Out:
# <Axes: xlabel='charges', ylabel='Count'>

# %% [markdown]
# <br>
#
# #### [실습] 한 수치형 변수에 대한 요약과 시각화
#
# 1. df_sp에서 'math score'의 평균 계산하기
# 2. df_sp에서 'math score'의 히스토그램 그려기
# 3. df_sp에서 'reading score'로 1~2. 반복하기

# %%
# df_sp에서 'math score'의 평균 계산하기 
col = 'math score'
df_sp[col].mean()
# Out:
# np.float64(66.089)

# %%
# df_sp에서 'math score'의 히스토그램 그려기
# histplot()을 활용한 히스토그램
sns.histplot(data=df_sp,
             x=col)
# Out:
# <Axes: xlabel='math score', ylabel='Count'>

# %%
# df_sp에서 'reading score'로 1~2. 반복하기

# %%
df_sp['reading score'].mean()
# Out:
# np.float64(69.169)

# %%
sns.histplot(data=df_sp,
             x='reading score')
# Out:
# <Axes: xlabel='reading score', ylabel='Count'>

# %% [markdown]
# <br>
#
#
# ### 2.3. 분위수와 상자그림
#
# `quantile()`을 활용해서 분위수를 계산 가능
#
# 사분위수(quartile)를 계산하고 상자그림(boxplot)으로 분포 확인
# * 최솟값(minimum, 0%)
# * Q1(1st Quartile, 25%)
# * 중앙값(median, 50%)
# * Q3(3rd Quartile, 75%)
# * 최댓값(maximum, 100%)

# %%
# 대표적인 3가지 순서통계량
df_ins['charges'].min()
df_ins['charges'].median()
df_ins['charges'].max()
# Out:
# np.float64(63770.42801)

# %%
# 분위수 계산
df_ins['charges'].quantile(0.1)
# Out:
# np.float64(2346.5336150000003)

# %%
# charges의 사분위수 계산
df_ins['charges'].quantile([0.0, 0.25, 0.5, 0.75, 1.0])
    ## quantile( ) : 계산할 분위(1.0이 최댓값) 를 리스트로 묶기
# Out:
# 0.00     1121.873900
# 0.25     4740.287150
# 0.50     9382.033000
# 0.75    16639.912515
# 1.00    63770.428010
# Name: charges, dtype: float64

# %%
# age의 사분위수 계산
df_ins['age'].quantile([0.0, 0.25, 0.5, 0.75, 1.0])
# Out:
# 0.00    18.0
# 0.25    27.0
# 0.50    39.0
# 0.75    51.0
# 1.00    64.0
# Name: age, dtype: float64

# %%
# boxplot()을 활용한 age의 상자그림
sns.boxplot(data=df_ins,
            y='age')
# Out:
# <Axes: ylabel='age'>

# %%
# boxplot()을 활용한 charges의 상자그림과 이상치
sns.boxplot(data=df_ins,
            y='charges')
# Out:
# <Axes: ylabel='charges'>

# %% [markdown]
# <br>
#
#
# #### [실습]
#
# 1. df_sp에서 'reading score'의 Q1(25%), 중위수(median, 50%), Q3(75%) 계산하기
# 2. df_sp에서 'reading score'의 상자그림 그리기
# 3. df_sp에서 'writing score'로 1~2. 반복하기

# %%
# df_sp에서 'reading score'의 Q1(25%), 중위수(median, 50%), Q3(75%) 계산하기
col_rs = "reading score"
df_sp[col_rs].min()
df_sp[col_rs].median()
df_sp[col_rs].max()
# Out:
# np.int64(100)

# %%
# df_sp에서 'reading score'의 Q1(25%), 중위수(median, 50%), Q3(75%) 계산하기
df_sp[col_rs].quantile([0.25, 0.5,0.75])
# Out:
# 0.25    59.0
# 0.50    70.0
# 0.75    79.0
# Name: reading score, dtype: float64

# %%
# df_sp에서 'reading score'의 상자그림 그리기
sns.boxplot(data =df_sp, y='reading score')
# Out:
# <Axes: ylabel='reading score'>

# %% [markdown]
# ## df_sp에서 'writing score'로 1~2. 반복하기

# %%
# df_sp에서 'writing score'의 Q1(25%), 중위수(median, 50%), Q3(75%) 계산하기
col_ws = "writing score"
df_sp[col_ws].quantile([0.25, 0.5,0.75])
# Out:
# 0.25    57.75
# 0.50    69.00
# 0.75    79.00
# Name: writing score, dtype: float64

# %%
# df_sp에서 'reading score'의 상자그림 그리기
sns.boxplot(data =df_sp, y='writing score')
# Out:
# <Axes: ylabel='writing score'>

# %% [markdown]
# <br>
# <br>
# <br>
#
# ## 3. 두 범주형 변수의 관계 탐색
#
# 두 범주형 변수의 관계 탐색을 위해서 `crosstab()`으로 **교차표**를 만들고 **열지도(heatmap)**를 활용해서 시각화

# %% [markdown]
# <br>
#
# ### 3.1. 교차표 생성과 열지도 그리기

# %%
# crosstab()을 활용한 교차표 생성
tab1 = pd.crosstab(df_ins['sex'], df_ins['smoker'])
tab1
# Out:
# smoker   no  yes
# sex
# female  547  115
# male    517  159

# %%
# 열지도 시각화
    # cmap : 색상 조합
    # annot=True : 수치 출력 여부
    # fmt : 수치 출력 형식, 'd' 정수, '.2f' 소수점 둘째자리 소수
sns.heatmap(tab1, cmap='YlGnBu', annot=True, fmt='d')
# Out:
# <Axes: xlabel='smoker', ylabel='sex'>

# %% [markdown]
# * 참고: [Color Palette](https://seaborn.pydata.org/tutorial/color_palettes.html)

# %% [markdown]
# <br>
#
# *crosstab( )*에서 `margins=True` 옵션을 활용하면 행, 열 합계, 전체 합계 등을 한번에 계산 가능

# %%
# crosstab()을 활용한 교차표 생성
tab1m = pd.crosstab(df_ins['sex'], df_ins['smoker'], margins=True)
tab1m
# Out:
# smoker    no  yes   All
# sex
# female   547  115   662
# male     517  159   676
# All     1064  274  1338

# %%
sns.heatmap(tab1m, cmap='YlGnBu', annot=True, fmt='d')
# Out:
# <Axes: xlabel='smoker', ylabel='sex'>

# %% [markdown]
# <br>
#
# ### 3.2. 행백분율과 열백분율의 계산과 열지도 그리기
#
# 두 변수의 관계를 제대로 파악하기 위해서는 상대적인 숫자 계산이 필수적
# `normalize=` 옵션을 활용해서 교차표에서 비율 계산 가능
#
# * `normalize='all'`: 전체 중 각 셀 비중
# * `normalize='index'`: 행 백분율(행 합계 중 각 셀의 비중)
# * `normalize='columns'`: 열 백분율(열 합계 중 각 셀의 비중)

# %%
# 전체 백분율
    # normalize : '정규화'
tab1_all = pd.crosstab(df_ins['sex'], df_ins['smoker'], normalize='all')
sns.heatmap(tab1_all, cmap='YlGnBu', annot=True, fmt='.2f')
# Out:
# <Axes: xlabel='smoker', ylabel='sex'>

# %%
# 행백분율
    # normalize='index'
tab1_idx = pd.crosstab(df_ins['sex'], df_ins['smoker'], normalize='index')
tab1_idx
sns.heatmap(tab1_idx, cmap='YlGnBu', annot=True, fmt='.2f')
# Out:
# <Axes: xlabel='smoker', ylabel='sex'>

# %%
# 열백분율
    # normalize='index'
tab1_col = pd.crosstab(df_ins['sex'], df_ins['smoker'], normalize='columns')
tab1_col
sns.heatmap(tab1_col, cmap='YlGnBu', annot=True, fmt='.2f')
# Out:
# <Axes: xlabel='smoker', ylabel='sex'>

# %%
# 전체 비율을 추가한 열백분율
    # margins=True
tab1_col = pd.crosstab(df_ins['sex'], df_ins['smoker'], normalize='columns', margins=True)
tab1_col
sns.heatmap(tab1_col, cmap='YlGnBu', annot=True, fmt='.2f')
# Out:
# <Axes: xlabel='smoker', ylabel='sex'>

# %% [markdown]
# #### [실습] 두 범주형 변수의 관계 탐색
#
# 1. df_sp에서 'race/ethnicity'와 'parental level of education'의 교차표 만들기
# 2. 1.의 교차표에 margin 추가하기
# 3. 1.의 교차표를 seaborn의 heatmap( )으로 열지도로 시각화하기
# 4. 2.의 교차표에서 행 백분율, 열 백분율 계산하고 시각화 하기
# 5. 'race/ethnicity'와 'parental level of education'의 관계 해석하기

# %% [markdown]
# ## df_sp에서 'race/ethnicity'와 'parental level of education'의 교차표 만들기

# %%
df_sp.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# df_sp에서 'race/ethnicity'와 'parental level of education'의 교차표 만들기
# crosstab()을 활용한 교차표 생성
tab_df_sp = pd.crosstab(df_sp['race/ethnicity'], df_sp['parental level of education'])
tab_df_sp
# Out:
# parental level of education  associate's degree  bachelor's degree  \
# race/ethnicity
# group A                                      14                 12
# group B                                      41                 20
# group C                                      78                 40
# group D                                      50                 28
# group E                                      39                 18
#
# parental level of education  high school  master's degree  some college  \
# race/ethnicity
# group A                               18                3            18
# group B                               48                6            37
# group C                               64               19            69
# group D                               44               23            67
# group E                               22                8            35
#
# parental level of education  some high school
# race/ethnicity
# group A                                    24
# group B                                    38
# group C                                    49
# group D                                    50
# group E                                    18

# %% [markdown]
# ## # 1.의 교차표에 margin 추가하기

# %% [markdown]
# *crosstab( )*에서 margins=True 옵션을 활용하면 행, 열 합계, 전체 합계 등을 한번에 계산 가능

# %%
# crosstab()을 활용한 교차표 생성
tab_df_sp_m = pd.crosstab(df_sp['race/ethnicity'], df_sp['parental level of education'], margins=True)
tab_df_sp_m
# Out:
# parental level of education  associate's degree  bachelor's degree  \
# race/ethnicity
# group A                                      14                 12
# group B                                      41                 20
# group C                                      78                 40
# group D                                      50                 28
# group E                                      39                 18
# All                                         222                118
#
# parental level of education  high school  master's degree  some college  \
# race/ethnicity
# group A                               18                3            18
# group B                               48                6            37
# group C                               64               19            69
# group D                               44               23            67
# group E                               22                8            35
# All                                  196               59           226
#
# parental level of education  some high school   All
# race/ethnicity
# group A                                    24    89
# group B                                    38   190
# group C                                    49   319
# group D                                    50   262
# group E                                    18   140
# All                                       179  1000

# %% [markdown]
# ## 1.의 교차표를 seaborn의 heatmap( )으로 열지도로 시각화하기

# %%
# 열지도 시각화
    # cmap : 색상 조합
    # annot=True : 수치 출력 여부
    # fmt : 수치 출력 형식, 'd' 정수, '.2f' 소수점 둘째자리 소수
sns.heatmap(tab_df_sp_m, cmap='YlGnBu', annot=True, fmt='d')
# Out:
# <Axes: xlabel='parental level of education', ylabel='race/ethnicity'>

# %% [markdown]
# ## 2.의 교차표에서 행 백분율, 열 백분율 계산하고 시각화 하기

# %%
# 전체 비율을 추가한 열백분율
    # margins=True
tab_col = pd.crosstab(df_sp['race/ethnicity'], df_sp['parental level of education'], normalize='columns', margins=True)
tab_col
sns.heatmap(tab_col, cmap='YlGnBu', annot=True, fmt='.2f')
# Out:
# <Axes: xlabel='parental level of education', ylabel='race/ethnicity'>

# %%
# 전체 비율을 추가한 행백분율
    # margins=True
tab_row = pd.crosstab(df_sp['race/ethnicity'], df_sp['parental level of education'], normalize='index', margins=True)
tab_row
sns.heatmap(tab_row, cmap='YlGnBu', annot=True, fmt='.2f')
# Out:
# <Axes: xlabel='parental level of education', ylabel='race/ethnicity'>

# %% [markdown]
# ## 'race/ethnicity'와 'parental level of education'의 관계 해석하기

# %% [markdown]
# <br>
# <br>
# <br>
#
# ## 4. 두 수치형 변수의 관계
#
# 두 수치형 변수의 관계는 **산점도(scatterplot)**를 그리고 **상관계수(correlation coefficient)**를 계산

# %%
# 예제 데이터 불러오기
    # 아빠키와 아들키
df_heights = pd.read_csv('data/heights.csv')
df_heights
# Out:
#           father         son
# 0     165.223215  151.836806
# 1     160.657388  160.563662
# 2     164.986513  160.889747
# 3     167.011350  159.492645
# 4     155.288564  163.274070
# ...          ...         ...
# 1073  170.171897  179.710893
# 1074  181.182797  173.400060
# 1075  182.329176  176.036961
# 1076  179.675460  176.027055
# 1077  178.577469  170.218100
#
# [1078 rows x 2 columns]

# %% [markdown]
# <br>
#
# ### 4.1. 산점도 그리기

# %%
# 각 변수 평균 계산
mean_f = df_heights['father'].mean()
mean_s = df_heights['son'].mean()
mean_f, mean_s
# Out:
# (np.float64(171.92522603599258), np.float64(174.45753692820037))

# %%
# seaborn으로 산점도 그래프 그리기 # scatterplot -> 상관관계 / 그림을 통해 유추해볼 수 있도록 산점도 그래프 그림 
# 대각선 -> 왼쪽 아래 - 오른쪽 대각선 -> 직선에 가까울 수도록 -> 상관관계가 깊다 
# 수직선 - 선형의 수직선 - 선에 가까울 수록 -> ex ) 아빠 키가 크면, 아들 키도 크다 / 선형에 안가까우면 아들과 아빠 키는 영향이 거의 없다로 판명 
plot_ = sns.scatterplot(data=df_heights, 
                        x='father', 
                        y='son', 
                        alpha=0.5) # alpha:1 에 가까울 수록 선명도 높아짐 
plot_.axhline(mean_s) # 수평선 추가
plot_.axvline(mean_f) # 수직선 추가
plot_
# Out:
# <Axes: xlabel='father', ylabel='son'>

# %% [markdown]
# <br>
#
# ### 4.2. 공분산과 상관 계수 계산

# %%
# 공분산 (얼만큼 값이 떨어져 있는지 / 붙어있는지 )계산하기
df_heights[['father','son']].cov() # 표준편차 -> 평균에서 얼마나 차이가 나는지
# Out:
#            father        son
# father  48.608307  24.989192
# son     24.989192  51.113092

# %%
# 상관계수 계산하기
df_heights[['father','son']].corr() # 0.5정도 상관관계가 구성되어 있음 -> 아빠키가 크다해서 아들키가 크다라고 할 수 없음 
# -1 ~ 1
# Out:
#           father       son
# father  1.000000  0.501338
# son     0.501338  1.000000

# %% [markdown]
# <br>
#
# #### [실습] 두 수치형 변수의 관계 탐색
#
# 1. **df_sp**에서 'math score'와 'reading score'의 산점도를 그리기
# 2. 1.의 그래프에 두 변수의 평균을 활용해서 수직선, 수평선 추가하기
# 3. 1.의 두 변수의 상관계수 계산하기
# 4. **df_ins**에서 bmi와 charges의 산점도를 그리고 상관계수 계산하기
# 5. df_ins에서 아래의 명령어를 실행하고 smoker별 분할 데이터로 bmi와 charges의 상관계수를 나눠 계산하기

# %% [markdown]
# ## df_sp에서 'math score'와 'reading score'의 산점도를 그리기

# %%
df_sp = pd.read_csv('data/StudentsPerformance.csv')
df_sp.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# 각 변수 평균 계산
mean_m = df_sp['math score'].mean()
mean_r = df_sp['reading score'].mean()
mean_m, mean_r
# Out:
# (np.float64(66.089), np.float64(69.169))

# %% [markdown]
# ## 1.의 그래프에 두 변수의 평균을 활용해서 수직선, 수평선 추가하기

# %%
# seaborn으로 산점도 그래프 그리기 # scatterplot -> 상관관계 / 그림을 통해 유추해볼 수 있도록 산점도 그래프 그림 
# 대각선 -> 왼쪽 아래 - 오른쪽 대각선 -> 직선에 가까울 수도록 -> 상관관계가 깊다 
# 수직선 - 선형의 수직선 - 선에 가까울 수록 -> ex ) 아빠 키가 크면, 아들 키도 크다 / 선형에 안가까우면 아들과 아빠 키는 영향이 거의 없다로 판명 
plot_sp = sns.scatterplot(data=df_sp, 
                        x='math score', 
                        y='reading score', 
                        alpha=0.5) # alpha:1 에 가까울 수록 선명도 높아짐 
plot_sp.axhline(mean_r) # 수평선 추가
plot_sp.axvline(mean_m) # 수직선 추가
plot_sp
# Out:
# <Axes: xlabel='math score', ylabel='reading score'>

# %% [markdown]
# ## 1.의 두 변수의 상관계수 계산하기

# %%
# 공분산 (얼만큼 값이 떨어져 있는지 / 붙어있는지 )계산하기
df_sp[['math score','reading score']].cov() # 공분산 : covariance
# Out:
#                math score  reading score
# math score     229.918998     180.998958
# reading score  180.998958     213.165605

# %% [markdown]
# ## df_ins에서 bmi와 charges의 산점도를 그리고 상관계수 계산하기

# %%
df_ins = pd.read_csv('data/insurance.csv')
df_ins.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# 각 변수 평균 계산
mean_ins_b = df_ins['bmi'].mean()
mean_ins_c = df_ins['charges'].mean()
mean_ins_b, mean_ins_c
# Out:
# (np.float64(30.66339686098655), np.float64(13270.422265141257))

# %%
# seaborn으로 산점도 그래프 그리기 # scatterplot -> 상관관계 / 그림을 통해 유추해볼 수 있도록 산점도 그래프 그림 
# 대각선 -> 왼쪽 아래 - 오른쪽 대각선 -> 직선에 가까울 수도록 -> 상관관계가 깊다 
# 수직선 - 선형의 수직선 - 선에 가까울 수록 -> ex ) 아빠 키가 크면, 아들 키도 크다 / 선형에 안가까우면 아들과 아빠 키는 영향이 거의 없다로 판명 
plot_ins = sns.scatterplot(data=df_ins, 
                        x='bmi', 
                        y='charges', 
                        alpha=0.5) # alpha:1 에 가까울 수록 선명도 높아짐 
plot_ins.axhline(mean_ins_c) # 수평선 추가
plot_ins.axvline(mean_ins_b) # 수직선 추가
plot_ins
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
# 공분산 (얼만큼 값이 떨어져 있는지 / 붙어있는지 )계산하기
df_ins[['bmi','charges']].cov()
# Out:
#                   bmi       charges
# bmi         37.187884  1.464730e+04
# charges  14647.304426  1.466524e+08

# %% [markdown]
# ## df_ins에서 아래의 명령어를 실행하고 smoker별 분할 데이터로 bmi와 charges의 상관계수를 나눠 계산하기

# %% [markdown]
# 상관계수 계산하기
# df_heights[['father','son']].corr() # 0.5정도 상관관계가 구성되어 있음 -> 아빠키가 크다해서 아들키가 크다라고 할 수 없음

# %%
# 5. 분할 데이터 생성 - 흡연여부에 따른 관측치 분할
df_ins_smoker = df_ins[df_ins['smoker'] == 'yes']
df_ins_nonsmoker = df_ins[df_ins['smoker'] == 'no'] # 학번, 이름, 흡연여부, 등등 -> 그 모든 데이터 안의 bmi, charges

# %%
df_ins_smoker
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 14     27    male  42.130         0    yes  southeast  39611.75770
# 19     30    male  35.300         0    yes  southwest  36837.46700
# 23     34  female  31.920         1    yes  northeast  37701.87680
# ...   ...     ...     ...       ...    ...        ...          ...
# 1313   19  female  34.700         2    yes  southwest  36397.57600
# 1314   30  female  23.655         3    yes  northwest  18765.87545
# 1321   62    male  26.695         0    yes  northeast  28101.33305
# 1323   42  female  40.370         2    yes  southeast  43896.37630
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [274 rows x 7 columns]

# %%
df_ins_nonsmoker
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 5      31  female  25.740         0     no  southeast   3756.62160
# ...   ...     ...     ...       ...    ...        ...          ...
# 1332   52  female  44.700         3     no  southwest  11411.68500
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
#
# [1064 rows x 7 columns]

# %%
df_ins_smoker[['bmi','charges']].cov()
# Out:
#                   bmi       charges
# bmi         39.925262  5.881415e+04
# charges  58814.152848  1.332073e+08

# %%
df_ins_nonsmoker[['bmi','charges']].cov()
# Out:
#                  bmi       charges
# bmi        36.519195  3.043895e+03
# charges  3043.895291  3.592542e+07

# %% [markdown]
# <br>
# <br>
# <br>
#
#
# ## 5. 범주형 변수와 수치형 변수의 관계
#
# 범주형 변수를 그룹처럼 활용해서 그룹별 평균을 계산하고, 그룹별 상자그림을 그려서 분포를 비교
# 한 변수의 집계에서 `groupby()`를 추가하면 되고, 필요에 따라 `agg()`를 활용 가능

# %% [markdown]
# <br>
#
# ### 5.1. 그룹별 집계값의 계산

# %%
# 한 수치형 변수의 평균 계산
df_ins['charges'].mean()
# Out:
# np.float64(13270.422265141257)

# %%
# 그룹별 평균 계산
df_ins.groupby('sex', as_index=False)['charges'].mean()
# Out:
#       sex       charges
# 0  female  12569.578844
# 1    male  13956.751178

# %% [markdown]
# <br>
#
# ### 5.2. 그래프를 활용한 그룹별 분포 비교
#
# **seaborn**의 그래프 함수에서 `hue=`옵션 등을 활용하면 그룹별로 색을 다르게 한 그래프 작성 가능

# %%
# charges의 히스토그램 
sns.histplot(data=df_ins, 
             x='charges')
# Out:
# <Axes: xlabel='charges', ylabel='Count'>

# %%
# sex에 따라 색을 다르게 겹쳐그린 히스토그램 
sns.histplot(data=df_ins, 
             x='charges',
             hue='sex')
# Out:
# <Axes: xlabel='charges', ylabel='Count'>

# %%
# 많이 겹치기 어려운 히스토그램
sns.histplot(data=df_ins, 
             x='charges',
             hue='region')
# Out:
# <Axes: xlabel='charges', ylabel='Count'>

# %%
# 그룹별 상자그림의 활용
sns.boxplot(data=df_ins,
            x='sex', 
            y='charges')
# Out:
# <Axes: xlabel='sex', ylabel='charges'>

# %%
# 더 많은 그룹을 나란하게 그린 상자그림
sns.boxplot(data=df_ins,
            x='region', 
            y='charges')
# Out:
# <Axes: xlabel='region', ylabel='charges'>

# %% [markdown]
# #### [실습] 변수 관계 탐색
#
# 1. 데이터 df_sp에서 `gender`별 `math score`의 평균을 계산하기
# 2. 1의 두 변수를 활용해서 히스토그램과 상자그림 그리기
# 3. 데이터 df_sp에서 `parental level of education`별 `reading score`의 평균 계산하기
# 4. 3의 두 변수를 활용해서 히스토그램과 상자그림 그리기

# %%
df_sp.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# ## 데이터 df_sp에서 gender별 math score의 평균을 계산하기

# %%
# 5. 분할 데이터 생성 - 흡연여부에 따른 관측치 분할
df_sp_female = df_sp[df_sp['gender'] == 'female']
df_sp_male = df_sp[df_sp['gender'] == 'male']

# %%
# 그룹별 평균 계산
df_sp.groupby('gender', as_index=False)['math score'].mean()
# Out:
#    gender  math score
# 0  female   63.633205
# 1    male   68.728216

# %%
mean_sp_female_m = df_sp_female['math score'].mean()
mean_sp_female_m
# Out:
# np.float64(63.633204633204635)

# %%
mean_sp_male_m =df_sp_male['math score'].mean()
mean_sp_male_m
# Out:
# np.float64(68.72821576763485)

# %% [markdown]
# ## 1의 두 변수를 활용해서 히스토그램과 상자그림 그리기

# %%
# sex에 따라 색을 다르게 겹쳐그린 히스토그램 
sns.histplot(data=df_sp, 
             x='math score',
             hue='gender')
# Out:
# <Axes: xlabel='math score', ylabel='Count'>

# %%
# 그룹별 상자그림의 활용
sns.boxplot(data=df_sp,
            x='gender', 
            y='math score')
# Out:
# <Axes: xlabel='gender', ylabel='math score'>

# %%
# plt.subplots () # 0-1 사이 
# 밀도선 -> kda = True

# %% [markdown]
# ## 데이터 df_sp에서 parental level of education별 reading score의 평균 계산하기

# %%
# 그룹별 평균 계산
df_sp.groupby('parental level of education', as_index=False)['reading score'].mean()
# Out:
#   parental level of education  reading score
# 0          associate's degree      70.927928
# 1           bachelor's degree      73.000000
# 2                 high school      64.704082
# 3             master's degree      75.372881
# 4                some college      69.460177
# 5            some high school      66.938547

# %% [markdown]
# ## 3의 두 변수를 활용해서 히스토그램과 상자그림 그리기

# %%
# parental level of education에 따라 색을 다르게 겹쳐그린 히스토그램 
sns.histplot(data=df_sp, 
             x='reading score',
             hue='parental level of education')
# Out:
# <Axes: xlabel='reading score', ylabel='Count'>

# %%
# 그룹별 상자그림의 활용
plt.figure(figsize = (12,4))
sns.boxplot(data=df_sp,
            x='parental level of education', 
            y='reading score')
plt.ylabel("Reading score")
plt.xlabel("Parental level of education")
plt.xticks(rotation = 25) # 시각적인 요소 

plt.title(" reading score by Parental level of education (Boxplot)")
plt.tight_layout() # 표에 맞춰져서 레이아웃이 출력됨 
plt.show()

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
#
# #### (참고) 피벗 테이블 활용

# %%
# pivot_table()을 활용한 피벗 테이블 생성
    ## index  : 행 그룹변수
    ## columns: 열 그룹변수 
    ## values : 값 변수
    ## aggfunc: 집계 함수
agg = df_ins.pivot_table(index='sex', columns='region', values='charges', aggfunc='size')
agg

# %%
# seaborn을 활용한 시각화
sns.heatmap(agg, cmap='YlGnBu', annot=True, fmt='.0f')

# %% [markdown]
# #### End of script
